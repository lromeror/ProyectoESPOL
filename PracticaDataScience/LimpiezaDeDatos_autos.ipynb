# %% [markdown]
# # **Allow access to my Drive Google**

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random as rd
import seaborn as sns

# %% [markdown]
# # **Dataset donde no nos dan los header**

# %%
#Importing Dataset
df =pd.read_csv("https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/auto.csv")
df
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# ..  ..  ...          ...     ...    ...   ...          ...  ...    ...    ...
# 199 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 200 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
# 201 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 202 -1   95        volvo  diesel  turbo  four        sedan  rwd  front  109.1
# 203 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   3            204 non-null    int64
#  1   ?            204 non-null    object
#  2   alfa-romero  204 non-null    object
#  3   gas          204 non-null    object
#  4   std          204 non-null    object
#  5   two          204 non-null    object
#  6   convertible  204 non-null    object
#  7   rwd          204 non-null    object
#  8   front        204 non-null    object
#  9   88.6         204 non-null    float64
#  10  168.8        204 non-null    float64
#  11  64.1         204 non-null    float64
#  12  48.8         204 non-null    float64
#  13  2548         204 non-null    int64
#  14  dohc         204 non-null    object
#  15  four         204 non-null    object
#  16  130          204 non-null    int64
#  17  mpfi         204 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['3', '?', 'alfa-romero', 'gas', 'std', 'two', 'convertible', 'rwd',
#        'front', '88.6', '168.8', '64.1', '48.8', '2548', 'dohc', 'four', '130',
#        'mpfi', '3.47', '2.68', '9.0', '111', '5000', '21', '27', '13495'],
#       dtype='object')

# %%
# Note: Headers were found in a separate file that was uploaded on UCI's website.
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df_automobile=pd.read_csv("https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/auto.csv")
df_automobile
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# ..  ..  ...          ...     ...    ...   ...          ...  ...    ...    ...
# 199 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 200 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
# 201 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 202 -1   95        volvo  diesel  turbo  four        sedan  rwd  front  109.1
# 203 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
#
# ...

# %%
df_automobile.columns
# Out:
# Index(['3', '?', 'alfa-romero', 'gas', 'std', 'two', 'convertible', 'rwd',
#        'front', '88.6', '168.8', '64.1', '48.8', '2548', 'dohc', 'four', '130',
#        'mpfi', '3.47', '2.68', '9.0', '111', '5000', '21', '27', '13495'],
#       dtype='object')

# %%
df_automobile.loc[df.shape[0]]=df.columns
df_automobile.columns=headers
df_automobile
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           1                 ?  alfa-romero       gas        std
# 2           2               164         audi       gas        std
# 3           2               164         audi       gas        std
# 4           2                 ?         audi       gas        std
# ..        ...               ...          ...       ...        ...
# 200        -1                95        volvo       gas      turbo
# 201        -1                95        volvo       gas        std
# 202        -1                95        volvo    diesel      turbo
# 203        -1                95        volvo       gas      turbo
# 204         3                 ?  alfa-romero       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location wheel-base  ...  \
# 0            two  convertible          rwd           front       88.6  ...
# ...

# %%
df_automobile2=pd.read_csv("https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/auto.csv",names=headers)
#Crear data Frame ahi si columns

df_automobile2
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# # Remplazo de los valores nulos a NAN

# %%
df_automobile2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df_automobile2.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df_automobile2.iloc[0,1]#posiciones
#Si hay simbolos raros debemos
#Llevarlos a NAN
# Out:
# '?'

# %%
missing_values=['n/a','na','missing']#Hay que darle sentido a los NaN
df_automobile2.replace('?',np.nan,inplace=True)
df_automobile2
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df_automobile2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
missing_data=df_automobile2.isnull()#Me dice cuantos T/F si es nulo
missing_data
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False               True  False      False       False         False
# 1        False               True  False      False       False         False
# 2        False               True  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
# 204      False              False  False      False       False         False
#
# ...

# %%
#Puedo ver cuanto hay de nulos
missing_data.sum(axis=0)#Sum es 0 col y 1 row
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %% [markdown]
# # Reemplazo de los NaN, dependiendo Media, Mode, Mediana

# %%
porcentajePerdida=(41/205)*100#Para el porcentaje de perdida de la columna
#Un 80 y 20porciento es posible eliminarla a la columna
porcentajePerdida
# Out:
# 20.0

# %%
df_automobile2['normalized-losses'].value_counts()#Podemos eliminar si son pocas las filas
#Solo me da cuantos hay de no nulos
# Out:
# 161    11
# 91      8
# 150     7
# 128     6
# 134     6
# 104     6
# 95      5
# 102     5
# 103     5
# 74      5
# 85      5
# 168     5
# 94      5
# 65      5
# 106     4
# 122     4
# 148     4
# 118     4
# 93      4
# 101     3
# 125     3
# 137     3
# 154     3
# 83      3
# 115     3
# 119     2
# 87      2
# 194     2
# 197     2
# 108     2
# 89      2
# 164     2
# 158     2
# 145     2
# 192     2
# 188     2
# 81      2
# 110     2
# 113     2
# 129     2
# 153     2
# 107     1
# 78      1
# 186     1
# 231     1
# 77      1
# 98      1
# 121     1
# 90      1
# 142     1
# 256     1
# Name: normalized-losses, dtype: int64

# %%
missing_data.sum(axis=0)

#price No media ni moda
#Podemos eliminar
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
#df_automobile2.drop('normalized-losses',axis=1)  
#Ahoravamos a rellenar

df_automobile2
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
type(df_automobile2['normalized-losses'].loc[10])
# Out:
# str

# %%
mean_value=df_automobile2['normalized-losses'].astype('float').mean()
mean_value
# Out:
# 122.0

# %%
df_automobile2['normalized-losses'].replace(np.nan,mean_value,inplace=True)
df_automobile2
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3             122.0  alfa-romero       gas        std
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
#Funcion Replace Media
#bore
#house 
def replace_Media(nameData,feature):
  mean_value=nameData[feature].astype('float').mean()
  nameData[feature].replace(np.nan,mean_value,inplace=True)

# %%
list_feature=['bore','stroke','horsepower','peak-rpm']
for fea in list_feature:
  replace_Media(df_automobile2,fea)

df_automobile2.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
#set_option permite ver la cantidad de conlunmas que tu quieras
pd.set_option('display.max_columns',df_automobile2.shape[1])
#Cantidad de columna
#df_automobile2

# %%
df_automobile2
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3             122.0  alfa-romero       gas        std
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %% [markdown]
# #Normalizar datos

# %%
df_automobile2['num-of-doors'].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %%
df_automobile2.groupby('num-of-doors').count()
#siempre necesita algo gruopby().sum()
# Out:
#               symboling  normalized-losses  make  fuel-type  aspiration  \
# num-of-doors
# four                114                114   114        114         114
# two                  89                 89    89         89          89
#
#               body-style  drive-wheels  engine-location  wheel-base  length  \
# num-of-doors
# four                 114           114              114         114     114
# two                   89            89               89          89      89
#
#               width  height  curb-weight  engine-type  num-of-cylinders  \
# num-of-doors
# four            114     114          114          114               114
# two              89      89           89           89                89
#
#               engine-size  fuel-system  bore  stroke  compression-ratio  \
# num-of-doors
# four                  114          114   114     114                114
# two                    89           89    89      89                 89
#
# ...

# %%
df_automobile2.groupby(['normalized-losses'])['normalized-losses'].count()
# Out:
# normalized-losses
# 122.0    41
# 101       3
# 102       5
# 103       5
# 104       6
# 106       4
# 107       1
# 108       2
# 110       2
# 113       2
# 115       3
# 118       4
# 119       2
# 121       1
# 122       4
# 125       3
# 128       6
# 129       2
# 134       6
# 137       3
# 142       1
# 145       2
# 148       4
# 150       7
# 153       2
# 154       3
# 158       2
# 161      11
# 164       2
# 168       5
# 186       1
# 188       2
# 192       2
# 194       2
# 197       2
# 231       1
# 256       1
# 65        5
# 74        5
# 77        1
# 78        1
# 81        2
# 83        3
# 85        5
# 87        2
# 89        2
# 90        1
# 91        8
# 93        4
# 94        5
# 95        5
# 98        1
# Name: normalized-losses, dtype: int64

# %%
df_automobile2.groupby(['normalized-losses','num-of-doors'])['normalized-losses'].count()
# Out:
# normalized-losses  num-of-doors
# 122.0              four            19
#                    two             21
# 101                two              3
# 102                four             5
# 103                four             5
#                                    ..
# 93                 four             3
#                    two              1
# 94                 four             5
# 95                 four             5
# 98                 two              1
# Name: normalized-losses, Length: 64, dtype: int64

# %%
df_automobile2.groupby(['num-of-doors']).count()
# Out:
#               symboling  normalized-losses  make  fuel-type  aspiration  \
# num-of-doors
# four                114                114   114        114         114
# two                  89                 89    89         89          89
#
#               body-style  drive-wheels  engine-location  wheel-base  length  \
# num-of-doors
# four                 114           114              114         114     114
# two                   89            89               89          89      89
#
#               width  height  curb-weight  engine-type  num-of-cylinders  \
# num-of-doors
# four            114     114          114          114               114
# two              89      89           89           89                89
#
#               engine-size  fuel-system  bore  stroke  compression-ratio  \
# num-of-doors
# four                  114          114   114     114                114
# two                    89           89    89      89                 89
#
# ...

# %%
df_automobile2.groupby(['normalized-losses']).count()
# Out:
#                    symboling  make  fuel-type  aspiration  num-of-doors  \
# normalized-losses
# 122.0                     41    41         41          41            40
# 101                        3     3          3           3             3
# 102                        5     5          5           5             5
# 103                        5     5          5           5             5
# 104                        6     6          6           6             6
# 106                        4     4          4           4             4
# 107                        1     1          1           1             1
# 108                        2     2          2           2             2
# 110                        2     2          2           2             2
# 113                        2     2          2           2             2
# 115                        3     3          3           3             3
# 118                        4     4          4           4             4
# ...

# %%
df_automobile2.groupby(['body-style','num-of-doors'])['num-of-doors'].count()
# Out:
# body-style   num-of-doors
# convertible  two              6
# hardtop      two              8
# hatchback    four            10
#              two             60
# sedan        four            79
#              two             15
# wagon        four            25
# Name: num-of-doors, dtype: int64

# %%
df_automobile2.groupby(['body-style','num-of-doors']).count()
#Es como decir me agrupe los carros que tienen body styl con tal numeros de puertas
#Cuantos autos que tienes  puerta de tal carro cuantos hay
# Out:
#                           symboling  normalized-losses  make  fuel-type  \
# body-style  num-of-doors
# convertible two                   6                  6     6          6
# hardtop     two                   8                  8     8          8
# hatchback   four                 10                 10    10         10
#             two                  60                 60    60         60
# sedan       four                 79                 79    79         79
#             two                  15                 15    15         15
# wagon       four                 25                 25    25         25
#
#                           aspiration  drive-wheels  engine-location  \
# body-style  num-of-doors
# convertible two                    6             6                6
# hardtop     two                    8             8                8
# hatchback   four                  10            10               10
# ...

# %%
df_automobile2['num-of-doors'].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %%
mode_door=df_automobile2['num-of-doors'].value_counts().idxmax()
#id_max() me sirve para sacar el id con mas valor
mode_door
# Out:
# 'four'

# %%
df_automobile2['num-of-doors'].replace(np.nan,mode_door,inplace=True)
df_automobile2.isnull().sum()
#El price podemos eliminar los registros son pocos
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df_automobile2.dropna(subset=['price'],axis=0,inplace=True)
#dropna borra todos los na pero le indicamos el eje
#drop borra pero le especifico que y eje 
#inplace es para que se guarde en el mismo dataFrame
df_automobile2.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df_automobile2.shape
# Out:
# (201, 26)

# %%
pd.set_option('display.max_columns', 500)
df_automobile2['length'] = df_automobile2['length']/df_automobile2['length'].max()

# %%
#Nomminal
#Queremos llevar los valores 
#si es gas 0
#o sino 1
#funcion lambda

#Se la usa con otra funcion

df_automobile2['fuel-type'].apply(lambda x: print(x)) #Aqui podemos aplicar lambda y ponerle funciones
# Out:
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# diesel
# gas
# gas
# diesel
# diesel
# diesel
# diesel
# diesel
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# diesel
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# diesel
# gas
# diesel
# gas
# diesel
# gas
# diesel
# gas
# diesel
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# gas
# diesel
# diesel
# gas
# gas
# gas
# ...

# %%
def funcion(x):
  return x

df_automobile2['fuel-type'].apply(funcion)
# Out:
# 0         gas
# 1         gas
# 2         gas
# 3         gas
# 4         gas
#         ...
# 200       gas
# 201       gas
# 202       gas
# 203    diesel
# 204       gas
# Name: fuel-type, Length: 201, dtype: object

# %% [markdown]
# # Visualizacion de la Data

# %%
#visualizacion
#corelacion
fig,ax=plt.subplots()
ax.scatter(df_automobile2['length'],df_automobile2['width'])
ax.set_title('Distribucion de longitud y ancho')
ax.set_xlabel('length')
ax.set_ylabel('widht')


#tiene forma lineal
# Out:
# Text(0, 0.5, 'widht')

# %%
fig,ax=plt.subplots()
ax.scatter(df_automobile2['bore'].astype('float'),df_automobile2['stroke'].astype('float'))
ax.set_title('Distribucion ')
ax.set_xlabel('bore')
ax.set_ylabel('stroke')
# Out:
# Text(0, 0.5, 'stroke')

# %%
gra=sns.FacetGrid()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-d40736e249b7> in <module>
# ----> 1 gra=sns.FacetGrid()
#
# TypeError: __init__() missing 1 required positional argument: 'data'

# %% [markdown]
# # **Data visual**

# %%
graph2=sns.FacetGrid(df_automobile2,col='fuel-type',row='body-style',height=4,aspect=1)#Es como es agrupar y despues relacion que
graph2.map(sns.scatterplot,'length','width')

# %%
graph3=sns.FacetGrid(df_automobile2,col='num-of-doors',row='body-style',height=4,aspect=1)#Devbemo pasar datos categroicos
#Es como es agrupar y despues relacion que
graph3.map(sns.scatterplot,'length','width')

# %%
graph4=sns.FacetGrid(df_automobile2,col='body-style',height=4,aspect=1)#Devbemo pasar datos categroicos
#Es como es agrupar y despues relacion que
graph4.map(sns.scatterplot,'length','width')

# %%
df_automobile2

# %%
#formula de la matriz de al correlacion
# Es la relacion que existe
df_automobile2.corr()
#Que tanto estan relacionados
# Out:
#                    symboling  wheel-base    length     width    height  \
# symboling           1.000000   -0.535987 -0.365404 -0.242423 -0.550160
# wheel-base         -0.535987    1.000000  0.876024  0.814507  0.590742
# length             -0.365404    0.876024  1.000000  0.857170  0.492063
# width              -0.242423    0.814507  0.857170  1.000000  0.306002
# height             -0.550160    0.590742  0.492063  0.306002  1.000000
# curb-weight        -0.233118    0.782097  0.880665  0.866201  0.307581
# engine-size        -0.110581    0.572027  0.685025  0.729436  0.074694
# compression-ratio  -0.182196    0.250313  0.159733  0.189867  0.259737
# city-mpg           -0.035527   -0.470606 -0.665192 -0.633531 -0.049800
# highway-mpg         0.036233   -0.543304 -0.698142 -0.680635 -0.104812
#
#                    curb-weight  engine-size  compression-ratio  city-mpg  \
# symboling            -0.233118    -0.110581          -0.182196 -0.035527
# ...

# %%
sns.heatmap(df_automobile2.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df_automobile2.corr(),cmap="Reds")
# Out:
# <Axes: >

# %%
plt.plot(df_automobile2['length'])

# %%
plt.plot(df_automobile2.price) #su usa para ver cambios en el tiempo

# %%
#Hsitrograma es para ver la frecuenciad e la data
#trata de los datos bins
#rangos de datos agrupados
plt.hist(df_automobile2['num-of-doors'])

# %%
plt.figure(figsize=(50,8))
plt.hist(df_automobile2['make'])#

# %%
plt.bar(df_automobile2.make,df_automobile2,edgecolor='black')

# %%
plt.boxplot(df_automobile2)
