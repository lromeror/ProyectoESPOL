# %%
#from google.colab import files
#uploaded = files.upload()
#Esto para los archivos subirlos de forma local
#import io
#df2 = pd.read_csv(io.BytesIO(uploaded['country_profile_variables.csv']))



#Otra forma
# Code to read csv file into Colaboratory:
#!pip install -U -q PyDrive
#from pydrive.auth import GoogleAuth
#from pydrive.drive import GoogleDrive
#from google.colab import auth
#from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
#auth.authenticate_user()
#gauth = GoogleAuth()
#gauth.credentials = GoogleCredentials.get_application_default()
#drive = GoogleDrive(gauth)
# Out:
# 9

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount("/content/gdrive", force_remount=True)
#
# ModuleNotFoundError: No module named 'google'

# %%
# Code to read csv file into Colaboratory:
'''!pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)'''
# Out:
# '!pip install -U -q PyDrive\nfrom pydrive.auth import GoogleAuth\nfrom pydrive.drive import GoogleDrive\nfrom google.colab import auth\nfrom oauth2client.client import GoogleCredentials\n\n# Authenticate and create the PyDrive client.\nauth.authenticate_user()\ngauth = GoogleAuth()\ngauth.credentials = GoogleCredentials.get_application_default()\ndrive = GoogleDrive(gauth)'

# %%
'link="https://drive.google.com/file/d/1JibA8owBynN50-2CmCWsbMdPJksyFmci/view?usp=share_link"'
# Out:
# 'link="https://drive.google.com/file/d/1JibA8owBynN50-2CmCWsbMdPJksyFmci/view?usp=share_link"'

# %%
'''id = '1JibA8owBynN50-2CmCWsbMdPJksyFmci'


downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('country_profile_variables.csv')  
df3 = pd.read_csv('country_profile_variables.csv')
# Dataset is now stored in a Pandas Dataframe

'''
# Out:
# "id = '1JibA8owBynN50-2CmCWsbMdPJksyFmci'\n\n\ndownloaded = drive.CreateFile({'id':id}) \ndownloaded.GetContentFile('country_profile_variables.csv')  \ndf3 = pd.read_csv('country_profile_variables.csv')\n# Dataset is now stored in a Pandas Dataframe\n\n"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Cargar dataset en google Colab

# %%
df=pd.read_csv('./gdrive/MyDrive/ProyectoESPOL/Datasets/country_profile_variables.csv')
df
# Out:
#                        country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# ...

# %%
pop_mean = round(df['Population in thousands (2017)'].mean(),0)
pop_mean
# Out:
# <ipython-input-38-d418fdffa71a>:3: RuntimeWarning: divide by zero encountered in double_scalars
#   return (num//factor)*factor+factor
# <ipython-input-38-d418fdffa71a>:3: RuntimeWarning: invalid value encountered in double_scalars
#   return (num//factor)*factor+factor
# nan

# %%
df['Population in thousands (2017)']
# Out:
# 0      35530
# 1       2930
# 2      41318
# 3         56
# 4         77
#        ...
# 224       12
# 225      553
# 226    28250
# 227    17094
# 228    16530
# Name: Population in thousands (2017), Length: 229, dtype: int64

# %%
pop_median=round(df['Population in thousands (2017)'].median(),0)
pop_median
# Out:
# <ipython-input-38-d418fdffa71a>:3: RuntimeWarning: divide by zero encountered in double_scalars
#   return (num//factor)*factor+factor
# <ipython-input-38-d418fdffa71a>:3: RuntimeWarning: invalid value encountered in double_scalars
#   return (num//factor)*factor+factor
# nan

# %%
plt.hist(df['Population in thousands (2017)']/100)
plt.title('Histogram of population distribution')
plt.xlabel('Population')
plt.ylabel('Number of countries')
plt.axvline(pop_mean,color='green')
plt.axvline(pop_median,color='red')

# %%
df.groupby(["Region"]).count()
# Out:
#                    country  Surface area (km2)  \
# Region
# Caribbean               25                  25
# CentralAmerica           8                   8
# CentralAsia              5                   5
# EasternAfrica           19                  19
# EasternAsia              7                   7
# EasternEurope           10                  10
# Melanesia                5                   5
# Micronesia               7                   7
# MiddleAfrica             9                   9
# NorthernAfrica           7                   7
# NorthernAmerica          5                   5
# NorthernEurope          13                  13
# Oceania                  2                   2
# Polynesia                9                   9
# South-easternAsia       11                  11
# SouthAmerica            14                  14
# SouthernAfrica           5                   5
# SouthernAsia             9                   9
# SouthernEurope          16                  16
# ...

# %%
df.groupby(["Region"])
df
# Out:
#                        country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# ...

# %%
#primero crear un data Frame con las columnas de country y populationThousan y populationDensity 
#crear una tabla con la frecuencia absoluta, absoluta acumalada relativa, relativa acumulada

import random as rd
list_id=list(range(df.shape[0]+1))
id_ale=rd.sample(list_id,20)

df_newDataFrame=df.iloc[id_ale]
#df_newDataFrame=df_newDataFrame[['country','Population in thousands (2017)','Population density (per km2, 2017)']]

df_newDataFrame
# Out:
#                     country          Region Surface area (km2)  \
# 163                   Qatar     WesternAsia              11607
# 49             Cook Islands       Polynesia                236
# 23                   Bhutan    SouthernAsia              38394
# 95                    India    SouthernAsia            3287263
# 90                    Haiti       Caribbean              27750
# 133                  Monaco   WesternEurope                  2
# 151                  Norway  NorthernEurope             386194
# 67                 Ethiopia   EasternAfrica            1104300
# 123                Maldives    SouthernAsia                300
# 142                   Nepal    SouthernAsia             147181
# 26   Bosnia and Herzegovina  SouthernEurope              51209
# 205                   Tonga       Polynesia                747
# 84               Guadeloupe       Caribbean               1705
# 125                   Malta  SouthernEurope                315
# ...

# %%
dr=df_newDataFrame.groupby('Population in thousands (2017)').count()
#dr
#Crear rango de cero a mill
#df_newDataFrame['PoblacionReal']=df_newDataFrame['Population in thousands (2017)']*1000

# %%
df_newDataFrame
# Out:
#                     country          Region Surface area (km2)  \
# 163                   Qatar     WesternAsia              11607
# 49             Cook Islands       Polynesia                236
# 23                   Bhutan    SouthernAsia              38394
# 95                    India    SouthernAsia            3287263
# 90                    Haiti       Caribbean              27750
# 133                  Monaco   WesternEurope                  2
# 151                  Norway  NorthernEurope             386194
# 67                 Ethiopia   EasternAfrica            1104300
# 123                Maldives    SouthernAsia                300
# 142                   Nepal    SouthernAsia             147181
# 26   Bosnia and Herzegovina  SouthernEurope              51209
# 205                   Tonga       Polynesia                747
# 84               Guadeloupe       Caribbean               1705
# 125                   Malta  SouthernEurope                315
# ...

# %%
df_newDataFrame.describe()
# Out:
#        Population in thousands (2017)  Population density (per km2, 2017)  \
# count                    2.000000e+01                           20.000000
# mean                     8.649605e+04                         1571.275000
# std                      2.991178e+05                         5756.887181
# min                      1.700000e+01                            4.000000
# 25%                      4.347500e+02                           62.900000
# 50%                      1.684500e+03                          177.200000
# 75%                      1.280325e+04                          321.000000
# max                      1.339180e+06                        25969.800000
#
#        Sex ratio (m per 100 f, 2017)  \
# count                       20.00000
# mean                       112.54500
# std                         45.57762
# min                         86.40000
# 25%                         97.20000
# 50%                        100.80000
# ...

# %%
def rango(Feature):
  max=Feature.max()
  min=Feature.min()
  rg=max-min
  return rg,max,min

rg,max,min=rango(df_newDataFrame['Population in thousands (2017)'])

ampl=rg/20
#print(ampl)
#ar=np.arange(min-1,max,ampl)
#print((ar))
fin=max+ampl+50
intervals = pd.interval_range(
    start=min,
    end=110213.6,
    freq=ampl,
    closed="left"
    )
print(fin)
# Out:
# 1406188.15

# %% [markdown]
# # **Tabla de Frecuencia para Population in thousands (2017)**

# %%
df_newDataFrame["inter"]=pd.cut(df_newDataFrame["Population in thousands (2017)"], intervals)
df_newDataFrame
# Out:
# <ipython-input-308-83a208b5aedc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_newDataFrame["inter"]=pd.cut(df_newDataFrame["Population in thousands (2017)"], intervals)
#                     country          Region Surface area (km2)  \
# 163                   Qatar     WesternAsia              11607
# 49             Cook Islands       Polynesia                236
# 23                   Bhutan    SouthernAsia              38394
# 95                    India    SouthernAsia            3287263
# 90                    Haiti       Caribbean              27750
# 133                  Monaco   WesternEurope                  2
# 151                  Norway  NorthernEurope             386194
# ...

# %%
df_Population.groupby('intervalos').count()
# Out:
#                   country  Population in thousands (2017)
# intervalos
# [17.0, 66975.15)       17                              17

# %%
datos =df_Population["Population in thousands (2017)"]


freq = ampl                # Amplitud de los intervalos
inf = datos.min()        # Limite inferior del primer intervalo

sup = datos.max()#+dif  # Limite superior del último intervalo

intervals = pd.interval_range(
    start=inf,
    end=sup+freq,
    freq=freq,
    name="Intervalo",
    closed="left"
    )

df = pd.DataFrame(index=intervals)
df["FreqAbs"] = pd.cut(datos, bins=df.index).value_counts()
df["Marca"]  = df.index.mid
df
# Out:
#                                           FreqAbs        Marca
# Intervalo
# [17.0, 66975.15)                               17    33496.075
# [66975.15, 133933.3)                            1   100454.225
# [133933.3, 200891.44999999998)                  0   167412.375
# [200891.44999999998, 267849.6)                  1   234370.525
# [267849.6, 334807.75)                           0   301328.675
# [334807.75, 401765.89999999997)                 0   368286.825
# [401765.89999999997, 468724.04999999993)        0   435244.975
# [468724.04999999993, 535682.2)                  0   502203.125
# [535682.2, 602640.35)                           0   569161.275
# [602640.35, 669598.5)                           0   636119.425
# [669598.5, 736556.6499999999)                   0   703077.575
# [736556.6499999999, 803514.7999999999)          0   770035.725
# [803514.7999999999, 870472.95)                  0   836993.875
# [870472.95, 937431.0999999999)                  0   903952.025
# ...
