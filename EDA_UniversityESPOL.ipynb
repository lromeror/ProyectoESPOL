# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('DataESPOL.csv')
df
# Out:
#      ANIO TERMINO        DIA     HORAINICIO         HORAFIN  \
# 0    2023      0S  miércoles  9:00:00 a. m.  11:00:00 a. m.
# 1    2023      0S      lunes  9:00:00 a. m.  12:00:00 p. m.
# 2    2023      0S  miércoles  2:00:00 p. m.   4:00:00 p. m.
# 3    2023      0S      lunes  2:00:00 p. m.   5:00:00 p. m.
# 4    2023      0S      lunes  9:00:00 a. m.  12:00:00 p. m.
# ..    ...     ...        ...            ...             ...
# 122  2023      0S  miércoles  2:00:00 p. m.   5:00:00 p. m.
# 123  2023      0S     martes  3:30:00 p. m.   5:00:00 p. m.
# 124  2023      0S     martes  3:30:00 p. m.   5:00:00 p. m.
# 125  2023      0S  miércoles  2:00:00 p. m.   5:00:00 p. m.
# 126  2023      0S     martes  3:30:00 p. m.   5:00:00 p. m.
#
#                                  NOMBRE    CODIGOMATERIA PARALELO ESQUINCENA  \
# 0                  PRODUCCIÓN VEGETAL I  AGRG1032            1,00          N
# 1                  PRODUCCIÓN VEGETAL I  AGRG1032            1,00          N
# ...

# %%
df['ANIO']
# Out:
# 0      2023
# 1      2023
# 2      2023
# 3      2023
# 4      2023
#        ...
# 122    2023
# 123    2023
# 124    2023
# 125    2023
# 126    2023
# Name: ANIO, Length: 127, dtype: int64
